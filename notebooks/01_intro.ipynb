# %% [markdown]
# # 📊 Dự án: Dự báo Thị trường Tài chính
#
# **Trọng tâm:** Phân tích & Dự đoán biến động giá
# **Bitcoin (BTC)**
#
# ---
#
# ## 🎯 Lợi thế dữ liệu
# Giao dịch 24/7 giúp dữ liệu có tính liên tục cao, loại bỏ hiện tượng "Gap" giá do đóng cửa cuối tuần.
#
# ---
#
# ## ⚠️ Thách thức
# Biến động mạnh (Volatility) và chịu ảnh hưởng cực lớn từ tâm lý đám đông (Sentiment Analysis).
#
# ---
#
# *Giai đoạn 1: Tập trung xây dựng mô hình cơ sở cho sản phẩm BTC trước khi mở rộng sang các tài sản khác.*
